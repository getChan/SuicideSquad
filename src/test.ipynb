# %%
import preprocessing as pre
from matplotlib import pyplot


if __name__ == '__main__':
    load_path = '../data/raw/cute/cute (1).mp4'
    frame = pre.VidToFrame(load_path)

    frame

# %%
frame
# Out:
# array([[[55, 55, 55, ..., 75, 72, 73],
#         [55, 55, 55, ..., 78, 74, 72],
#         [55, 55, 55, ..., 78, 77, 71],
#         ...,
#         [49, 49, 50, ..., 72, 74, 79],
#         [50, 49, 50, ..., 72, 74, 79],
#         [51, 49, 49, ..., 73, 74, 79]],
#
#        [[55, 55, 55, ..., 75, 74, 72],
#         [55, 55, 55, ..., 77, 75, 72],
#         [55, 55, 55, ..., 77, 80, 72],
#         ...,
#         [50, 50, 50, ..., 71, 72, 75],
#         [49, 50, 52, ..., 71, 71, 74],
#         [51, 50, 50, ..., 72, 71, 73]],
#
#        [[55, 55, 55, ..., 74, 73, 72],
#         [55, 55, 55, ..., 78, 79, 74],
#         [55, 55, 55, ..., 75, 78, 70],
#         ...,
#         [50, 50, 50, ..., 71, 73, 79],
#         [50, 50, 50, ..., 72, 72, 76],
#         [50, 50, 50, ..., 74, 73, 73]],
#
#        ...,
#
#        [[51, 51, 51, ..., 63, 62, 64],
#         [51, 51, 51, ..., 64, 62, 64],
#         [51, 51, 51, ..., 64, 61, 63],
#         ...,
#         [48, 48, 47, ..., 68, 68, 68],
# ...

# %%
pyplot.imshow(frame[0])
